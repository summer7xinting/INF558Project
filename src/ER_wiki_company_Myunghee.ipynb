# %%
import pandas as pd
import rltk
import re

wikicom = pd.read_csv("wikidata.csv", encoding='utf8')
jobscom = pd.read_csv("merged_jobs.csv", encoding='utf8')

# %%
# remove "(United States)" from the company name

wikiList = [company.split(" (United States)")[0].lower() for company in wikicom['URILabel']]

# %%
wikicom['URILabel'] = wikiList

# %%
wikicom.sort_values(by= 'URILabel', axis=0, ascending=True, inplace=True, kind='quicksort', na_position='last')
wikicom.reset_index(drop=True, inplace=True)

# %%
wikicom.fillna(-1, inplace=True)

# %%
comList = list(jobscom['Company Name'])
wikiList = list(wikicom['URILabel'])
comset = sorted(set(comList))
wikiset = sorted(set(wikiList))

# %%
simDic = dict()
for com1 in comset:
    for com2 in wikiset:
        if com1[0] == com2[0]:
            sim = rltk.jaro_winkler_similarity(com1, com2)
            if sim > 0.8:
                simDic.update({(com1, com2): sim})
        elif com1[0] < com2[0]:
            break

# %%
match = dict()
matchedKey = list()
for key in simDic:
    if simDic[key] == 1:
        key0 = key[0]
        match.update({key0:wikicom.iloc[wikiList.index(key0)][0]})
        matchedKey.append(key0)

# %%
new_dict = {key:val for key, val in simDic.items() if key[0] not in matchedKey and key[1] not in matchedKey}

# %%
len(new_dict)
# Out:
# 3274

# %%
def getCleanName (key):    
    newkey = re.sub(r" corporation", "", key)
    newkey = re.sub(r" incorporation", "", newkey)
    newkey = re.sub(r"[.,]", "",newkey)
    newkey = re.sub(r" llc", "", newkey)
    newkey = re.sub(r" inc", "", newkey)
    newkey = re.sub(r" corp", "", newkey)
    newkey = re.sub(r" co", "", newkey)
    newkey = re.sub(r"&", "", newkey)
    newkey = re.sub(r" and ", " ", newkey)
    newkey = re.sub(r"  ", " ", newkey)
    newkey = re.sub(r"technologies", "technology", newkey)
    newkey = re.sub(r"laboratories", "labs", newkey)    
    return newkey

# %%
matchedKey0 = list()
matchedKey1 = list()
for key in new_dict:
    key0 = key[0]
    key1 = key[1]
    key2 = getCleanName(key[0])
    key3 = getCleanName(key[1])
    sim = rltk.jaro_winkler_similarity(key2, key3)
    if sim == 1:
        match.update({key0: wikicom.iloc[wikiList.index(key1)][0]}) 
        matchedKey0.append(key0)
        matchedKey1.append(key1)

# %%
len(match)
# Out:
# 128

# %%
new_dict = {key:val for key, val in new_dict.items() if key[0] not in matchedKey0 and key[1] not in matchedKey1}

# %%
len(new_dict)
# Out:
# 3131

# %%
def getURL (url):
    if url !=-1:
        newurl = re.sub(r".com", "", url)
        newurl = re.sub(r".org", "", url)
        newurl = re.sub(r"www.", "", newurl)
        newurl = re.sub(r"http:", "", newurl)
        newurl = re.sub(r"https:", "", newurl)
        newurl = re.sub(r"[:/.]", "", newurl)
        return newurl
    else:
        return -1

# %%
# website == comURI, and name similarity > 0.8
matchedKey0 = list()
matchedKey1 = list()
for key in new_dict:
    key0 = key[0]
    key1 = key[1]
    website = getURL(jobscom.iloc[comList.index(key0)][1])
    comURI = getURL(wikicom.iloc[wikiList.index(key1)][2])    
    if website == comURI and website !=-1:
        match.update({key0: wikicom.iloc[wikiList.index(key1)][0]}) 
        matchedKey0.append(key0)
        matchedKey1.append(key1)

# %%
len(match)
# Out:
# 128

# %%
new_dict = {key:val for key, val in new_dict.items() if key[0] not in matchedKey0 and key[1] not in matchedKey1}

# %%
len(new_dict)
# Out:
# 3131

# %%
cnt = 0
for key, val in new_dict.items():
    if val >= 0.9:
        cnt +=1
        print(key, val)
# Out:
# ('acxiom', 'axiom') 0.9500000000000001
# ('acxiom', 'axiomx') 0.9
# ('alin', 'albion') 0.9111111111111111
# ('amica mutual', 'amica mutual insurance') 0.9090909090909091
# ('amrock', 'amerock') 0.9619047619047619
# ('applied memetics llc', 'applied stemcell') 0.9349999999999999
# ('applied research laboratories', 'applied behavioral research') 0.9015989782886334
# ('applied research laboratories', 'applied research associates') 0.9182950191570881
# ('applied research laboratories', 'applied research corporation') 0.9119458128078818
# ('applied research laboratories', 'applied science laboratories') 0.9029852216748768
# ('armis', 'artemis') 0.9238095238095239
# ('arrow electronics', 'argo electric') 0.9010558069381599
# ('assured information security, inc. (ais)', 'assured information security') 0.9400000000000001
# ('attainment company', 'attainment') 0.9111111111111111
# ('audible', 'audible.com') 0.9272727272727272
# ('audible', 'audiofile') 0.9047619047619048
# ('avant', 'advanta') 0.9142857142857143
# ('avant', 'avantgen') 0.925
# ('bectran', 'beltran') 0.9238095238095239
# ('berg health', 'banner health') 0.9034965034965035
# ('blue cross and blue shield of north carolina', 'blue cross and blue shield of minnesota') 0.9315850815850816
# ('brightside', 'brightspec') 0.92
# ('caci international', 'cpi international') 0.9490196078431372
# ('carbon3d', 'carbon') 0.95
# ('carbon3d', 'carbonix') 0.9
# ('catalyte', 'catalant') 0.9
# ('catalyte', 'catalist') 0.9
# ('centauri', 'centrify') 0.9
# ('centauri', 'centuri') 0.975
# ('centauri', 'centurion') 0.9305555555555555
# ('centauri', 'century') 0.9214285714285715
# ('centauri', 'centurylink') 0.9022727272727272
# ('centizen', 'centice') 0.9214285714285715
# ('centro', 'centrak') 0.9095238095238095
# ('centro', 'centrose') 0.95
# ('centro', 'centuri') 0.9095238095238095
# ('centro', 'centurion') 0.9333333333333333
# ('centro', 'century') 0.9095238095238095
# ('cibersql', 'ciber') 0.925
# ('citi', 'citibank') 0.9
# ('clearedge', 'clean edge') 0.9377777777777778
# ('clearedge', 'clearedge power') 0.92
# ('clinc', 'clinacuity') 0.9
# ('cognizance technologies', 'cognitive technologies') 0.9063657166631994
# ('comerica bank', 'comerica') 0.9230769230769231
# ('confluent', 'confluence') 0.9377777777777778
# ('dematic', 'demaco') 0.9095238095238095
# ('dematic', 'demandtec') 0.9047619047619048
# ('digital turbine', 'digital fuel') 0.9
# ('digital turbine', 'digital pictures') 0.9050641025641025
# ('digital turbine', 'digitalthink') 0.9
# ('everlaw', 'everlane') 0.9214285714285715
# ('everlaw', 'everlast') 0.9214285714285715
# ('ga telesis', 'gelesis') 0.91
# ('general dynamics land systems', 'general dynamics') 0.9103448275862069
# ('govtech', 'glotech') 0.9142857142857143
# ('group o', 'group of fifty') 0.9
# ('group o', 'group w') 0.9428571428571428
# ('icw group', 'icg group') 0.9074074074074073
# ('ignw', 'ign') 0.9416666666666667
# ('inertia systems', 'intersystems') 0.9244444444444444
# ('information builders', 'information ventures') 0.9075
# ('infosys', 'innosys') 0.9238095238095239
# ('kinetica db', 'kineta') 0.9090909090909091
# ('kinetica db', 'kinetic bei') 0.9272727272727274
# ('kinetica db', 'kinetico') 0.9022727272727272
# ('l3 harris technologies', 'l3harris technologies') 0.9497835497835498
# ('logikcull', 'logik') 0.9111111111111111
# ('luminar technologies', 'liuman technologies') 0.953421052631579
# ('mantech', 'matech') 0.9619047619047619
# ('masergy communications', 'mrv communications') 0.9151515151515152
# ('massmutual', 'magmutual') 0.9170370370370371
# ('memorial health system', 'memorial health center') 0.9161616161616162
# ('moda operandi', 'modus operandi') 0.9487179487179487
# ('modus technologies', 'mips technologies') 0.9147058823529411
# ('modus technologies', 'miro technologies') 0.9147058823529411
# ('modus technologies', 'moai technologies') 0.9241830065359478
# ('modus technologies', 'mod9 technologies') 0.9603485838779956
# ('modus technologies', 'mos technology') 0.9068783068783068
# ('modus technologies', 'muse technologies') 0.9302696078431372
# ('nask', 'nsk') 0.9249999999999999
# ('national grid usa', 'national grid') 0.9529411764705882
# ('novartis', 'nortis') 0.9333333333333333
# ('novartis', 'novarials') 0.9305555555555555
# ('novartis', 'novasterilis') 0.9083333333333333
# ('novartis', 'novastor') 0.9214285714285715
# ('optex systems', 'optipro systems') 0.9018803418803418
# ('optex systems', 'optron systems') 0.9141025641025641
# ('osf healthcare system', 'osf healthcare') 0.9333333333333333
# ('peoplesbank', 'peoples bank') 0.9833333333333333
# ('peraton', 'patreon') 0.9142857142857143
# ('pivotal commware', 'pivotal software') 0.925
# ('raytheon', 'raytheon company') 0.9
# ('red ventures', 'rre ventures') 0.9499999999999998
# ('regeneron', 'regenerex') 0.9111111111111111
# ('robert half', 'robertshaw') 0.9054545454545454
# ('saama technologies inc', 'sa technologies') 0.9151515151515152
# ('samsung next', 'samsung') 0.9166666666666667
# ('santander', 'santander bank') 0.9285714285714286
# ('santander', 'santen') 0.9
# ('seats incorporated', 'saks incorporated') 0.9490196078431372
# ('seats incorporated', 'sealift incorporated') 0.9383115468409586
# ('sentilink', 'sentien') 0.9047619047619048
# ('shine systems', 'sapien systems') 0.909065934065934
# ('solugenix corporation', 'soundwell corporation') 0.9089947089947089
# ('sooryen technologies', 'sorbent technologies') 0.9318518518518519
# ('sooryen technologies', 'synkera technologies') 0.9233333333333333
# ('synechron', 'synchronoss') 0.9104377104377104
# ('synechron', 'synthecon') 0.9189814814814814
# ('synergis', 'synergia') 0.95
# ('takeda pharmaceuticals', 'takeda pharmaceuticals north america') 0.9222222222222222
# ('technology navigators', 'technology dynamics') 0.9007518796992481
# ('the clorox company', 'the doctors company') 0.9211988304093567
# ('the clorox company', 'the hoover company') 0.92
# ('the clorox company', 'the offshore company') 0.9033333333333333
# ('the e.w. scripps company', 'the spaceship company') 0.9077067669172931
# ('the squires group', 'the burke group') 0.9262745098039216
# ('tivity health', 'trinity health') 0.934065934065934
# ('true fit', 'true') 0.9
# ('universal technologies (ny)', 'universal technology corporation') 0.9054247181964573
# ('verisilicon', 'verisign') 0.9022727272727272
# ('verisilicon', 'veriskin') 0.9022727272727272

# %% [markdown]
# ('digitalocean', 'digital ocean'), ('peoplesbank', 'peoples bank'), ('nestle', 'nestlé'),
# ('takeda pharmaceuticals', 'takeda pharmaceuticals north america')
# ('trilogy ed', 'trilogy')
# ('universal technologies (ny)', 'universal technology corporation')

# %% [markdown]
# key = matchedKey[12]
# print(wikicom.iloc[wikiList.index(key)][0])
# print(wikicom.iloc[wikiList.index(key)][1])
# print(wikicom.iloc[wikiList.index(key)][2])
# print(jobscom.iloc[comList.index(key)][0])
# print(jobscom.iloc[comList.index(key)][1])

# %%
match
# Out:
# {'23andme': 'http://www.wikidata.org/entity/Q216272',
#  'abb': 'http://www.wikidata.org/entity/Q30338853',
#  'acceleron pharma': 'http://www.wikidata.org/entity/Q16824238',
#  'accuride international': 'http://www.wikidata.org/entity/Q4672917',
#  'adient': 'http://www.wikidata.org/entity/Q26832896',
#  'adobe': 'http://www.wikidata.org/entity/Q11463',
#  'advanced bioscience laboratories': 'http://www.wikidata.org/entity/Q30253430',
#  'agios pharmaceuticals': 'http://www.wikidata.org/entity/Q30286564',
#  'altec': 'http://www.wikidata.org/entity/Q30255008',
#  'amazon': 'http://www.wikidata.org/entity/Q3884',
#  'amyris': 'http://www.wikidata.org/entity/Q4749580',
#  'associated banc-corp': 'http://www.wikidata.org/entity/Q4809155',
#  'assurant': 'http://www.wikidata.org/entity/Q4810399',
#  'asurion': 'http://www.wikidata.org/entity/Q4811938',
#  'autodesk': 'http://www.wikidata.org/entity/Q628051',
#  'axon': 'http://www.wikidata.org/entity/Q30254995',
#  'biogen': 'http://www.wikidata.org/entity/Q864338',
#  'biomarin pharmaceutical': 'http://www.wikidata.org/entity/Q4914632',
#  'bluebird bio': 'http://www.wikidata.org/entity/Q30256843',
#  'blueprint medicines': 'http://www.wikidata.org/entity/Q56582970',
#  'buckman': 'http://www.wikidata.org/entity/Q4983398',
#  'cadence design systems': 'http://www.wikidata.org/entity/Q608776',
#  'capgemini': 'http://www.wikidata.org/entity/Q30255471',
#  'capital one': 'http://www.wikidata.org/entity/Q1034654',
#  'cdk global': 'http://www.wikidata.org/entity/Q55454124',
#  'church & dwight': 'http://www.wikidata.org/entity/Q5116536',
#  'cloudflare': 'http://www.wikidata.org/entity/Q4778915',
#  'cybercoders': 'http://www.wikidata.org/entity/Q23016736',
#  'dynetics': 'http://www.wikidata.org/entity/Q5319205',
#  'edwards lifesciences': 'http://www.wikidata.org/entity/Q16966841',
#  'ellie mae': 'http://www.wikidata.org/entity/Q16974631',
#  'ensco, inc.': 'http://www.wikidata.org/entity/Q5323729',
#  'esri': 'http://www.wikidata.org/entity/Q1045778',
#  'exelixis': 'http://www.wikidata.org/entity/Q5419989',
#  'genentech': 'http://www.wikidata.org/entity/Q899140',
#  'general atomics': 'http://www.wikidata.org/entity/Q1501547',
#  'genesys': 'http://www.wikidata.org/entity/Q5532852',
#  'glassdoor': 'http://www.wikidata.org/entity/Q15954148',
#  'godaddy': 'http://www.wikidata.org/entity/Q1416215',
#  'gopro': 'http://www.wikidata.org/entity/Q733482',
#  'greenlight biosciences': 'http://www.wikidata.org/entity/Q30259097',
#  'idaho central credit union': 'http://www.wikidata.org/entity/Q16996524',
#  'ihs markit': 'http://www.wikidata.org/entity/Q1662481',
#  'invitae': 'http://www.wikidata.org/entity/Q30263140',
#  'irobot': 'http://www.wikidata.org/entity/Q285161',
#  'jlg industries': 'http://www.wikidata.org/entity/Q12060878',
#  'john deere': 'http://www.wikidata.org/entity/Q496302',
#  'juniper networks': 'http://www.wikidata.org/entity/Q1049080',
#  'keybank': 'http://www.wikidata.org/entity/Q1740314',
#  'leidos': 'http://www.wikidata.org/entity/Q502132',
#  'liveramp': 'http://www.wikidata.org/entity/Q344935',
#  'marklogic': 'http://www.wikidata.org/entity/Q6766381',
#  'mathworks': 'http://www.wikidata.org/entity/Q1518683',
#  'maxar technologies': 'http://www.wikidata.org/entity/Q48791239',
#  'micro focus': 'http://www.wikidata.org/entity/Q55453804',
#  'n.f. smith & associates': 'http://www.wikidata.org/entity/Q16931794',
#  'natera': 'http://www.wikidata.org/entity/Q30256747',
#  'new england biolabs': 'http://www.wikidata.org/entity/Q17134414',
#  'new relic': 'http://www.wikidata.org/entity/Q7011152',
#  'next': 'http://www.wikidata.org/entity/Q7020945',
#  'noblis': 'http://www.wikidata.org/entity/Q7045871',
#  'northrop grumman': 'http://www.wikidata.org/entity/Q329953',
#  'novetta': 'http://www.wikidata.org/entity/Q64141841',
#  'nvidia': 'http://www.wikidata.org/entity/Q182477',
#  'orbit logic': 'http://www.wikidata.org/entity/Q30298324',
#  'oregon mutual insurance': 'http://www.wikidata.org/entity/Q7101273',
#  'oshkosh corporation': 'http://www.wikidata.org/entity/Q1969091',
#  'pepsico': 'http://www.wikidata.org/entity/Q334800',
#  'pfizer': 'http://www.wikidata.org/entity/Q206921',
#  'pharmavite': 'http://www.wikidata.org/entity/Q7180840',
#  'pierce manufacturing': 'http://www.wikidata.org/entity/Q7191814',
#  'pitney bowes': 'http://www.wikidata.org/entity/Q428977',
#  'pra health sciences': 'http://www.wikidata.org/entity/Q17092519',
#  'precision biosciences': 'http://www.wikidata.org/entity/Q30288396',
#  'q2 solutions': 'http://www.wikidata.org/entity/Q54854375',
#  'qualys': 'http://www.wikidata.org/entity/Q7268802',
#  'quantlab': 'http://www.wikidata.org/entity/Q82759040',
#  'regenxbio': 'http://www.wikidata.org/entity/Q56583534',
#  'reynolds american': 'http://www.wikidata.org/entity/Q947718',
#  'rockwell automation': 'http://www.wikidata.org/entity/Q1529234',
#  'rubius therapeutics': 'http://www.wikidata.org/entity/Q81654756',
#  'saab': 'http://www.wikidata.org/entity/Q30298502',
#  'sartorius': 'http://www.wikidata.org/entity/Q30267522',
#  'schweitzer engineering laboratories': 'http://www.wikidata.org/entity/Q7433236',
#  'scs engineers': 'http://www.wikidata.org/entity/Q30298527',
#  'securityscorecard': 'http://www.wikidata.org/entity/Q54954068',
#  'seracare life sciences': 'http://www.wikidata.org/entity/Q30283543',
#  'sevone': 'http://www.wikidata.org/entity/Q7457067',
#  'specialized bicycle components': 'http://www.wikidata.org/entity/Q1200510',
#  'starbucks': 'http://www.wikidata.org/entity/Q37158',
#  'sumo logic': 'http://www.wikidata.org/entity/Q7638010',
#  'tecolote research': 'http://www.wikidata.org/entity/Q30298652',
#  'teradata': 'http://www.wikidata.org/entity/Q430745',
#  'the climate corporation': 'http://www.wikidata.org/entity/Q7723390',
#  'the hartford': 'http://www.wikidata.org/entity/Q444110',
#  'thousandeyes': 'http://www.wikidata.org/entity/Q19750589',
#  'timesys': 'http://www.wikidata.org/entity/Q7804859',
#  'torc robotics': 'http://www.wikidata.org/entity/Q30694374',
#  'transunion': 'http://www.wikidata.org/entity/Q7833641',
#  'two sigma': 'http://www.wikidata.org/entity/Q18355352',
#  'usaa': 'http://www.wikidata.org/entity/Q7865722',
#  'ust global': 'http://www.wikidata.org/entity/Q2471622',
#  'veracyte': 'http://www.wikidata.org/entity/Q61933493',
#  'verizon': 'http://www.wikidata.org/entity/Q467752',
#  'visa inc.': 'http://www.wikidata.org/entity/Q328840',
#  'wandisco': 'http://www.wikidata.org/entity/Q7946626',
#  'wepay': 'http://www.wikidata.org/entity/Q7977212',
#  'western digital': 'http://www.wikidata.org/entity/Q738770',
#  'willis towers watson': 'http://www.wikidata.org/entity/Q21189883',
#  'xilinx': 'http://www.wikidata.org/entity/Q1046482',
#  'zynga': 'http://www.wikidata.org/entity/Q245772',
#  'atricure, inc.': 'http://www.wikidata.org/entity/Q30256881',
#  'cerus corporation': 'http://www.wikidata.org/entity/Q30281710',
#  'dcs corp': 'http://www.wikidata.org/entity/Q30282885',
#  'frontier technology inc.': 'http://www.wikidata.org/entity/Q30297974',
#  'icon health and fitness': 'http://www.wikidata.org/entity/Q5986621',
#  'innovative interfaces, inc': 'http://www.wikidata.org/entity/Q16996986',
#  'intellipro group inc.': 'http://www.wikidata.org/entity/Q30290114',
#  'karyopharm therapeutics inc.': 'http://www.wikidata.org/entity/Q30281289',
#  'mantech international corporation': 'http://www.wikidata.org/entity/Q6746136',
#  'mitre': 'http://www.wikidata.org/entity/Q627039',
#  'netskope': 'http://www.wikidata.org/entity/Q17082991',
#  'proofpoint': 'http://www.wikidata.org/entity/Q4047452',
#  'ptc therapeutics, inc.': 'http://www.wikidata.org/entity/Q7120959',
#  'qinetiq north america.': 'http://www.wikidata.org/entity/Q29000155',
#  'systems & technology research': 'http://www.wikidata.org/entity/Q30298598',
#  'techsmith corporation': 'http://www.wikidata.org/entity/Q7692139',
#  'workday': 'http://www.wikidata.org/entity/Q8034666'}

# %%
uris = [val for key, val in match.items()]

# %%
rowList = list()
for i in range(len(wikicom)):
    if wikicom.iloc[i]['URI'] in uris:
        rowList.append(i)

# %%
len(rowList)
# Out:
# 281

# %%
df = wikicom.iloc[rowList]

# %%
df
df.reset_index(drop=True, inplace=True)

# %%
import json
f = open("company-wikiurl.json", mode = "w+")
json.dump(match, f)
f.close()

# %%
df.to_csv(r'wikidata2.csv', index = False, header=True)

# %%
df
# Out:
#                                           URI  \
# 0      http://www.wikidata.org/entity/Q216272
# 1      http://www.wikidata.org/entity/Q216272
# 2      http://www.wikidata.org/entity/Q216272
# 10   advanced bioscience laboratories               http://www.ablinc.com/
# 11              agios pharmaceuticals                                   -1
# 12                              altec                http://www.altec.com/
# 13                             amazon               https://www.amazon.com
# 14                             amazon               https://www.amazon.com
# 15                             amazon               https://www.amazon.com
# 16                             amazon               https://www.amazon.com
# 17                             amazon               https://www.amazon.com
# 18                             amazon               https://www.amazon.com
# 19                             amazon               https://www.amazon.com
# 20                             amazon               https://www.amazon.com
# 21                             amazon               https://www.amazon.com
# 22                             amazon               https://www.amazon.com
# 23                             amazon               https://www.amazon.com
# 24                             amazon               https://www.amazon.com
# 25                             amazon               https://www.amazon.com
# 26                             amazon               https://www.amazon.com
# 27                             amazon               https://www.amazon.com
# 28                             amazon               https://www.amazon.com
# 29                             amazon               https://www.amazon.com
# ..                                ...                                  ...
# 251                           timesys              http://www.timesys.com/
# 252                     torc robotics                       http://torc.ai
# 253                        transunion           http://www.transunion.com/
# 254                         two sigma            https://www.twosigma.com/
# 255                         two sigma            https://www.twosigma.com/
# 256                              usaa                https://www.usaa.com/
# 257                        ust global           http://www.ust-global.com/
# 258                          veracyte            https://www.veracyte.com/
# 259                           verizon              http://www.verizon.com/
# 260                           verizon              http://www.verizon.com/
# 261                           verizon              http://www.verizon.com/
# 262                           verizon              http://www.verizon.com/
# 263                         visa inc.                 http://www.visa.com/
# 264                         visa inc.             https://www.visa.com.tr/
# 265                         visa inc.                 http://www.visa.com/
# 266                         visa inc.             https://www.visa.com.tr/
# 267                          wandisco                                   -1
# 268                             wepay                 https://go.wepay.com
# 269                   western digital       https://www.westerndigital.com
# 270                   western digital       https://www.westerndigital.com
# 271                   western digital       https://www.westerndigital.com
# 272                   western digital       https://www.westerndigital.com
# 273                   western digital       https://www.westerndigital.com
# 274              willis towers watson  https://www.willistowerswatson.com/
# 275                     workday, inc.             https://www.workday.com/
# 276                     workday, inc.             https://www.workday.com/
# 277                     workday, inc.             https://www.workday.com/
# 278                     workday, inc.             https://www.workday.com/
# 279                            xilinx               http://www.xilinx.com/
# 280                             zynga                     http://zynga.com
#
#                                    founded_by       founded_byLabel  \
# 0     http://www.wikidata.org/entity/Q2069573         Anne Wojcicki
# 1     http://www.wikidata.org/entity/Q2069744            Linda Avey
# 2    http://www.wikidata.org/entity/Q13377793          Paul Cusenza
# 3                                          -1                    -1
# 4                                          -1                    -1
# 5                                          -1                    -1
# 6                                          -1                    -1
# 7                                          -1                    -1
# 8     http://www.wikidata.org/entity/Q1344392          John Warnock
# 9     http://www.wikidata.org/entity/Q2959209       Charles Geschke
# 10                                         -1                    -1
# 11                                         -1                    -1
# 12                                         -1                    -1
# 13     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 14     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 15     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 16     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 17     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 18     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 19     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 20     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 21     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 22     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 23     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 24     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 25     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 26     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 27     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 28     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# 29     http://www.wikidata.org/entity/Q312556            Jeff Bezos
# ..                                        ...                   ...
# 251                                        -1                    -1
# 252                                        -1                    -1
# 253                                        -1                    -1
# 254  http://www.wikidata.org/entity/Q29860142         John Overdeck
# 255  http://www.wikidata.org/entity/Q33092670          David Siegel
# 256                                        -1                    -1
# 257                                        -1                    -1
# 258                                        -1                    -1
# 259   http://www.wikidata.org/entity/Q2843047      AT&T Corporation
# 260   http://www.wikidata.org/entity/Q2843047      AT&T Corporation
# 261   http://www.wikidata.org/entity/Q2843047      AT&T Corporation
# 262   http://www.wikidata.org/entity/Q2843047      AT&T Corporation
# 263   http://www.wikidata.org/entity/Q5249916              Dee Hock
# 264   http://www.wikidata.org/entity/Q5249916              Dee Hock
# 265   http://www.wikidata.org/entity/Q5249916              Dee Hock
# 266   http://www.wikidata.org/entity/Q5249916              Dee Hock
# 267  http://www.wikidata.org/entity/Q16213415  David James Richards
# 268                                        -1                    -1
# 269                                        -1                    -1
# 270                                        -1                    -1
# 271                                        -1                    -1
# 272                                        -1                    -1
# 273                                        -1                    -1
# 274                                        -1                    -1
# 275   http://www.wikidata.org/entity/Q5233095        David Duffield
# 276   http://www.wikidata.org/entity/Q5233095        David Duffield
# 277  http://www.wikidata.org/entity/Q18352311          Aneel Bhusri
# 278  http://www.wikidata.org/entity/Q18352311          Aneel Bhusri
# 279                                        -1                    -1
# 280    http://www.wikidata.org/entity/Q729842           Mark Pincus
#
#                                           CEO          CEOLabel  \
# 0     http://www.wikidata.org/entity/Q2069573     Anne Wojcicki
# 1     http://www.wikidata.org/entity/Q2069573     Anne Wojcicki
# 2     http://www.wikidata.org/entity/Q2069573     Anne Wojcicki
# 3                                          -1                -1
# 4                                          -1                -1
# 5                                          -1                -1
# 6                                          -1                -1
# 7                                          -1                -1
# 8     http://www.wikidata.org/entity/Q2622748  Shantanu Narayen
# 9     http://www.wikidata.org/entity/Q2622748  Shantanu Narayen
# 10                                         -1                -1
# 11                                         -1                -1
# 12                                         -1                -1
# 13     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 14     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 15     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 16     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 17     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 18     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 19     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 20     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 21     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 22     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 23     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 24     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 25     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 26     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 27     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 28     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# 29     http://www.wikidata.org/entity/Q312556        Jeff Bezos
# ..                                        ...               ...
# 251                                        -1                -1
# 252  http://www.wikidata.org/entity/Q59398264   Michael Fleming
# 253                                        -1                -1
# 254                                        -1                -1
# 255                                        -1                -1
# 256  http://www.wikidata.org/entity/Q33843537     Stuart Parker
# 257                                        -1                -1
# 258                                        -1                -1
# 259   http://www.wikidata.org/entity/Q1872576     Lowell McAdam
# 260   http://www.wikidata.org/entity/Q1872576     Lowell McAdam
# 261   http://www.wikidata.org/entity/Q1872576     Lowell McAdam
# 262   http://www.wikidata.org/entity/Q1872576     Lowell McAdam
# 263  http://www.wikidata.org/entity/Q36556725   Alfred F. Kelly
# 264  http://www.wikidata.org/entity/Q36556725   Alfred F. Kelly
# 265  http://www.wikidata.org/entity/Q36556725   Alfred F. Kelly
# 266  http://www.wikidata.org/entity/Q36556725   Alfred F. Kelly
# 267                                        -1                -1
# 268                                        -1                -1
# 269                                        -1                -1
# 270                                        -1                -1
# 271                                        -1                -1
# 272                                        -1                -1
# 273                                        -1                -1
# 274                                        -1                -1
# 275   http://www.wikidata.org/entity/Q5233095    David Duffield
# 276  http://www.wikidata.org/entity/Q18352311      Aneel Bhusri
# 277  http://www.wikidata.org/entity/Q18352311      Aneel Bhusri
# 278   http://www.wikidata.org/entity/Q5233095    David Duffield
# 279                                        -1                -1
# 280    http://www.wikidata.org/entity/Q729842       Mark Pincus
#
#                                     parent parentLabel  \
# 0                                       -1          -1
# 1                                       -1          -1
# 2                                       -1          -1
# 3    http://www.wikidata.org/entity/Q52825   ABB Group
# 4                                       -1          -1
# 5                                       -1          -1
# 6                                       -1          -1
# 7                                       -1          -1
# 8                                       -1          -1
# 9                                       -1          -1
# 10                                      -1          -1
# 11                                      -1          -1
# 12                                      -1          -1
# 13                                      -1          -1
# 14                                      -1          -1
# 15                                      -1          -1
# 16                                      -1          -1
# 17                                      -1          -1
# 18                                      -1          -1
# 19                                      -1          -1
# 20                                      -1          -1
# 21                                      -1          -1
# 22                                      -1          -1
# 23                                      -1          -1
# 24                                      -1          -1
# 25                                      -1          -1
# 26                                      -1          -1
# 27                                      -1          -1
# 28                                      -1          -1
# 29                                      -1          -1
# ..                                     ...         ...
# 251                                     -1          -1
# 252                                     -1          -1
# 253                                     -1          -1
# 254                                     -1          -1
# 255                                     -1          -1
# 256                                     -1          -1
# 257                                     -1          -1
# 258                                     -1          -1
# 259                                     -1          -1
# 260                                     -1          -1
# 261                                     -1          -1
# 262                                     -1          -1
# 263                                     -1          -1
# 264                                     -1          -1
# 265                                     -1          -1
# 266                                     -1          -1
# 267                                     -1          -1
# 268                                     -1          -1
# 269                                     -1          -1
# 270                                     -1          -1
# 271                                     -1          -1
# 272                                     -1          -1
# 273                                     -1          -1
# 274                                     -1          -1
# 275                                     -1          -1
# 276                                     -1          -1
# 277                                     -1          -1
# 278                                     -1          -1
# 279                                     -1          -1
# 280                                     -1          -1
#
#                                    subsidiary  \
# 0                                          -1
# 1                                          -1
# 2                                          -1
# 3                                          -1
# 4                                          -1
# 5                                          -1
# 6    http://www.wikidata.org/entity/Q52853020
# 7    http://www.wikidata.org/entity/Q52855351
# 8    http://www.wikidata.org/entity/Q16927817
# 9    http://www.wikidata.org/entity/Q16927817
# 10                                         -1
# 11                                         -1
# 12                                         -1
# 13    http://www.wikidata.org/entity/Q6418754
# 14    http://www.wikidata.org/entity/Q7581878
# 15    http://www.wikidata.org/entity/Q7719162
# 16   http://www.wikidata.org/entity/Q15279566
# 17   http://www.wikidata.org/entity/Q21175463
# 18   http://www.wikidata.org/entity/Q22688437
# 19   http://www.wikidata.org/entity/Q22906322
# 20   http://www.wikidata.org/entity/Q28129037
# 21    http://www.wikidata.org/entity/Q1663991
# 22   http://www.wikidata.org/entity/Q46973305
# 23   http://www.wikidata.org/entity/Q48732422
# 24   http://www.wikidata.org/entity/Q58196054
# 25   http://www.wikidata.org/entity/Q67937344
# 26   http://www.wikidata.org/entity/Q73136791
# 27   http://www.wikidata.org/entity/Q73136962
# 28    http://www.wikidata.org/entity/Q5449851
# 29   http://www.wikidata.org/entity/Q30315155
# ..                                        ...
# 251                                        -1
# 252                                        -1
# 253                                        -1
# 254                                        -1
# 255                                        -1
# 256                                        -1
# 257                                        -1
# 258                                        -1
# 259     http://www.wikidata.org/entity/Q27585
# 260  http://www.wikidata.org/entity/Q29231846
# 261    http://www.wikidata.org/entity/Q919641
